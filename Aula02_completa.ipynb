# %% [markdown]
# <a href="https://colab.research.google.com/github/Aiyato/testes-colab/blob/main/Aula02_completa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulo 2

# %% [markdown]
# ### Rodando a sua IA no Google Colab

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('Gemini_API_Keyh')

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="O que é a Inteligência Artificial?"
    )

# %%
print(resposta.text)
# Out:
# A Inteligência Artificial (IA), ou Artificial Intelligence (AI) em inglês, é um **campo da ciência da computação que se dedica a criar sistemas ou máquinas capazes de simular, emular ou mimetizar a inteligência humana**. O objetivo é permitir que computadores realizem tarefas que normalmente exigiriam a cognição humana.
#
# Em termos mais simples, a IA busca fazer com que as máquinas possam:
#
# 1.  **Aprender:** Adquirir informações e regras para usar as informações, sem serem explicitamente programadas para cada cenário. (Ex: Machine Learning).
# 2.  **Raciocinar:** Usar regras para chegar a conclusões aproximadas ou definitivas.
# 3.  **Resolver problemas:** Tomar decisões com base no raciocínio e na aprendizagem.
# 4.  **Perceber:** Compreender o ambiente através de dados sensoriais (visão, audição).
# 5.  **Compreender a linguagem:** Processar e gerar linguagem humana (Processamento de Linguagem Natural - PNL).
#
# ### Como a IA funciona (de forma simplificada)?
#
# ...

# %% [markdown]
# ### Estruturas de Repetição, Loops, Laços

# %%
print("***************")
# Out:
# ***************

# %%
n = 1

while n <= 10:
    print("*")
    n = n + 1
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
chat = client.chats.create(model="gemini-2.5-flash")

# %%
resposta = chat.send_message("O que é a Inteligência Artificial?")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)**, ou Artificial Intelligence (AI) em inglês, é um campo da ciência da computação focado na criação de máquinas ou sistemas que podem simular e reproduzir capacidades cognitivas tipicamente associadas à inteligência humana.
#
# Em termos mais simples, a IA busca desenvolver computadores e softwares que possam **aprender, raciocinar, resolver problemas, perceber, compreender a linguagem humana e tomar decisões**, tal como um ser humano faria, mas muitas vezes em escalas e velocidades muito maiores.
#
# **Componentes e Conceitos Chave da IA:**
#
# 1.  **Aprendizagem (Machine Learning - ML):** É a base da maioria das IAs modernas. Permite que os sistemas aprendam com dados, identifiquem padrões e tomem decisões ou previsões sem serem explicitamente programados para cada tarefa.
# ...

# %%
resposta = chat.send_message("Quando foi lançado o ChatGPT?")
print(resposta.text)
# Out:
# O ChatGPT foi lançado em **30 de novembro de 2022** pela OpenAI.

# %%
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='O que é a Inteligência Artificial?'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""A **Inteligência Artificial (IA)**, ou Artificial Intelligence (AI) em inglês, é um campo da ciência da computação focado na criação de máquinas ou sistemas que podem simular e reproduzir capacidades cognitivas tipicamente associadas à inteligência humana.
#
#  Em termos mais simples, a IA busca desenvolver computadores e softwares que possam **aprender, raciocinar, resolver problemas, perceber, compreender a linguagem humana e tomar decisões**, tal como um ser humano faria, mas muitas vezes em escalas e velocidades muito maiores.
#
#  **Componentes e Conceitos Chave da IA:**
#
# ...

# %%
prompt = input("Digite a sua pergunta: ")

while prompt != "fim":
    resposta = chat.send_message(prompt)
    print(resposta.text)
    print("\n")
    prompt = input("Digite a sua pergunta: ")
# Out:
# Digite a sua pergunta: Quem é você?
# Eu sou um modelo de linguagem grande, treinado pelo Google. Fui desenvolvido para ajudar com informações, gerar texto, responder perguntas e interagir de forma conversacional.
#
#
# Digite a sua pergunta: fim

# %% [markdown]
# ### Estruturas de dados

# %% [markdown]
# #### Listas

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
#                      0               1               2              3                4

# %%
print(lista_de_nomes[3])
# Out:
# Pedro Costa

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
print(lista_de_medias)
# Out:
# [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
print(lista_de_medias[3])
# Out:
# 1.4

# %% [markdown]
# Desafio: Crie um código que percorra a lista de médias e some 1 a cada valor, exceto quando o valor passar de 10.0, que aí ele deve parar em 10.0.

# %%
n = 0

while n < 5:
    lista_de_medias[n] = lista_de_medias[n] + 1.0
    if lista_de_medias[n] > 10.0:
        lista_de_medias[n] = 10.0

    n = n + 1

print(lista_de_medias)
# Out:
# [9.9, 8.5, 5.2, 2.4, 10.0]

# %%
len(lista_de_medias)
# Out:
# 5

# %%
n = 0

while n < len(lista_de_medias):
    lista_de_medias[n] = lista_de_medias[n] + 1.0
    if lista_de_medias[n] > 10.0:
        lista_de_medias[n] = 10.0

    n = n + 1

print(lista_de_medias)
# Out:
# [10.0, 9.5, 6.2, 3.4, 10.0]

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
print(lista_de_medias)
# Out:
# [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
lista_de_medias[len(lista_de_medias) - 1]
# Out:
# 9.5

# %%
lista_de_medias[-1]
# Out:
# 9.5

# %%
lista_de_medias[-2]
# Out:
# 1.4

# %% [markdown]
# #### Particionando uma lista

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira']

# %%
lista_de_nomes[1:3]
# Out:
# ['João Santos', 'Ana Oliveira']

# %%
lista_de_nomes[1:4]
# Out:
# ['João Santos', 'Ana Oliveira', 'Pedro Costa']

# %%
lista_de_nomes[1:]
# Out:
# ['João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira']

# %%
lista_de_nomes[0:4]
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa']

# %%
lista_de_nomes[:4]
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa']

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira']

# %%
lista_de_nomes.append("Fábio Carraro")

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Fábio Carraro']

# %%
len(lista_de_nomes)
# Out:
# 6

# %%
lista_de_nomes.append("Joana da Silva", "Paulo Silveira")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2968458327.py in <cell line: 0>()
# ----> 1 lista_de_nomes.append("Joana da Silva", "Paulo Silveira")
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
lista_de_nomes.extend(["Joana da Silva", "Paulo Silveira"])

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Fábio Carraro',
#  'Joana da Silva',
#  'Paulo Silveira']

# %%
lista_de_nomes.append(["Márcio Costa", "Natália Pedreira"])

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Fábio Carraro',
#  'Joana da Silva',
#  'Paulo Silveira',
#  ['Márcio Costa', 'Natália Pedreira']]

# %%
lista_de_nomes[8]
# Out:
# ['Márcio Costa', 'Natália Pedreira']

# %%
lista_de_nomes[8][0]
# Out:
# 'Márcio Costa'

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
#                      0               1               2              3                4

# %%
lista_de_nomes.extend(["Joana da Silva", "Paulo Silveira"])

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Joana da Silva',
#  'Paulo Silveira']

# %%
lista_de_nomes.remove("Paulo Silveira")

# %%
lista_de_nomes
# Out:
# ['Maria Silva',
#  'João Santos',
#  'Ana Oliveira',
#  'Pedro Costa',
#  'Juliana Pereira',
#  'Joana da Silva']

# %%
lista_de_nomes.pop()
print(lista_de_nomes)
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira']

# %%
lista_de_nomes.pop(2)
print(lista_de_nomes)
# Out:
# ['Maria Silva', 'João Santos', 'Pedro Costa', 'Juliana Pereira']

# %% [markdown]
# #### Dicionários<br>"chave":valor

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
dict_de_nomes_e_medias = {"Maria Silva":8.9,
                         "João Santos":7.5,
                         "Ana Oliveira":4.2,
                         "Pedro Costa":1.4,
                         "Juliana Pereira":9.5}

# %%
dict_de_nomes_e_medias["Maria Silva"]
# Out:
# 8.9

# %%
dict_de_nomes_e_medias.get("Maria Silva")
# Out:
# 8.9

# %%
dict_de_nomes_e_medias.pop("Juliana Pereira")
# Out:
# 9.5

# %%
dict_de_nomes_e_medias
# Out:
# {'Maria Silva': 8.9,
#  'João Santos': 7.5,
#  'Ana Oliveira': 4.2,
#  'Pedro Costa': 1.4}

# %%
dict_de_nomes_e_medias.items()
# Out:
# dict_items([('Maria Silva', 8.9), ('João Santos', 7.5), ('Ana Oliveira', 4.2), ('Pedro Costa', 1.4)])

# %%
dict_de_nomes_e_medias.keys()
# Out:
# dict_keys(['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa'])

# %%
dict_de_nomes_e_medias.values()
# Out:
# dict_values([8.9, 7.5, 4.2, 1.4])

# %% [markdown]
# Desafio: Usar dicionários de forma que as chaves sejam "nome" e "média", e os valores, sejam os nomes e médias dos alunos

# %%
dict_desafio = [
    {"nome": "Maria Silva", "média": 8.9},
    {"nome": "João Santos", "média": 7.5},
    {"nome": "Ana Oliveira", "média": 4.2},
    {"nome": "Pedro Costa", "média": 1.4}
]

# %%
dict_desafio[0]
# Out:
# {'nome': 'Maria Silva', 'média': 8.9}

# %%
dict_desafio[0]["média"]
# Out:
# 8.9

# %%
gerar_lista_emails = [
        "Reunião de Alinhamento - Projeto X",
        "Confirmação de Compra: Pedido #9283",
        "Seu acesso foi realizado em um novo dispositivo",
        "Convite: Churrasco no próximo sábado 🥩",
        "Atualização dos Termos de Serviço",
        "Lembrete: Pagamento de fatura pendente",
        "Feedback sobre a entrevista de ontem",
        "Oferta imperdível: 50% de desconto em toda a loja!",
        "Resumo semanal da sua conta",
        "Nova mensagem de João no LinkedIn",
        "Planejamento de Férias 2026 ✈️",
        "Relatório Mensal de Performance - Janeiro",
        "Seu código de verificação: 482910",
        "Urgente: Problema no servidor de produção",
        "Newsletter: As principais notícias de hoje",
        "Parabéns! Você ganhou um bônus de fidelidade",
        "Solicitação de alteração de senha",
        "Happy Hour da firma - Quinta-feira",
        "Documento compartilhado com você no Drive",
        "Aviso de manutenção programada"
        ]

# %%
def resumidor_de_emails(lista_de_emails):
    for email in enumerate(lista_de_emails):
      resposta = client.models.generate_content(
          model="gemini-2.5-flash",
          contents=f"vou te mandar o corpo de um email. quero que voce o resuma com apenas uma linha, passando o intuito daquele e-mail. segue o e-mail:{email}"
          )
      print(f"E-mail {numero + 1}: {resposta.text}")
      print("-" * 50)

# %%
resumidor_de_emails(gerar_lista_emails)

# %%
# !pip install -q groq

# %%
import os
from google.colab import userdata
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
# Out:
# ---------------------------------------------------------------------------
# NotebookAccessError                       Traceback (most recent call last)
# /tmp/ipython-input-862778598.py in <cell line: 0>()
#       1 import os
#       2 from google.colab import userdata
# ----> 3 os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
# ---> 70     raise NotebookAccessError(key)
#      71   return resp.get('payload', '')
#
# NotebookAccessError: Notebook does not have access to secret GROQ_API_KEY

# %%
from groq import Groq

client = Groq()
completion = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
      {
        "role": "user",
        "content": "DE QUE E FEITO O SOL?"
      }
    ],
    temperature=1, #0 o menos criativo possivel; #2 o mais criativo possivel.
    max_completion_tokens=8192,
    top_p=1,
    reasoning_effort="medium",
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2337688011.py in <cell line: 0>()
# ----> 1 from groq import Groq
#       2
#       3 client = Groq()
#       4 completion = client.chat.completions.create(
#       5     model="openai/gpt-oss-20b",
#
# ModuleNotFoundError: No module named 'groq'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd

# %%
df = pd.read_csv("respostas2.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1800521196.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("respostas2.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
lista_de_perguntas = [
    "como vou fazer para arrumar um emprego?",
    "por que e tao dificil?",
    "a culpa e minha?",
    "quando o  brasil vai melhorar?",
    "como estudar certo?",
    "sera que esse curso da escola da nuvem vai realmente me ajudar a arrumar um emprego?",
    "o que sera de mim se eu n conseguir?",
    "e as minhas dividas?",
    "e o meu futuro?",
    "o que fazer?"



]
with open("perguntas.txt", "w", encoding="utf-8") as arquivo:
  for pergunta in lista_de_perguntas:
    arquivo.write(pergunta + "\n")

# %%
lista_desafio = []

with open("perguntas.txt", "r", encoding="utf-8") as arquivo:
  for linha in arquivo:
    lista_desafio.append(linha.strip())
print(lista_desafio)
# Out:
# ['como vou fazer para arrumar um emprego?', 'por que e tao dificil?', 'a culpa e minha?', 'quando o  brasil vai melhorar?', 'como estudar certo?', 'sera que esse curso da escola da nuvem vai realmente me ajudar a arrumar um emprego?', 'o que sera de mim se eu n conseguir?', 'e as minhas dividas?', 'e o meu futuro?', 'o que fazer?']

# %%
lista_de_dicionarios_de_respostas = []

for pergunta in lista_desafio:
    resposta = client.models.generate_content(
      model="gemini-2.5-flash",
      contents= f"Gere uma resposta muito sucinta para a pergunta:{pergunta}"
      )
    lista_de_dicionarios_de_respostas.append({"pergunta":pergunta, "resposta":resposta.text})
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-2812017175.py in <cell line: 0>()
#       2
#       3 for pergunta in lista_desafio:
# ----> 4     resposta = client.models.generate_content(
#       5       model="gemini-2.5-flash",
#       6       contents= f"Gere uma resposta muito sucinta para a pergunta:{pergunta}"
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5472     while remaining_remote_calls_afc > 0:
#    5473       i += 1
# -> 5474       response = self._generate_content(
#    5475           model=model, contents=contents, config=parsed_config
#    5476       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4212     request_dict = _common.encode_unserializable_types(request_dict)
#    4213
# ...

# %%
lista_de_dicionarios_de_respostas
# Out:
# [{'pergunta': 'como vou fazer para arrumar um emprego?',
#   'resposta': 'Defina seu objetivo, prepare seu currículo, pesquise vagas, faça networking e candidate-se ativamente.'},
#  {'pergunta': 'por que e tao dificil?',
#   'resposta': 'Complexidade e desafios.'},
#  {'pergunta': 'a culpa e minha?', 'resposta': 'Provavelmente não.'},
#  {'pergunta': 'quando o  brasil vai melhorar?',
#   'resposta': 'A cada dia, com esforço.'},
#  {'pergunta': 'como estudar certo?', 'resposta': 'Compreender e praticar.'},
#  {'pergunta': 'sera que esse curso da escola da nuvem vai realmente me ajudar a arrumar um emprego?',
#   'resposta': 'Sim, pode, e muito, mas depende do seu esforço e do mercado.'},
#  {'pergunta': 'o que sera de mim se eu n conseguir?',
#   'resposta': 'Você se adaptará.'}]

# %%
with open("'respostas1.csv", "w", encoding="utf-8") as arquivo:
  arquivo.write("pergunta,resposta\n")
  for pergunta_dict in lista_de_dicionarios_de_respostas:
      arquivo.write(f"{pergunta_dict['pergunta']},{pergunta_dict['resposta']}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2267799779.py in <cell line: 0>()
#       1 with open("'respostas1.csv", "w", encoding="utf-8") as arquivo:
#       2   arquivo.write("pergunta,resposta\n")
# ----> 3   for pergunta_dict in lista_de_dicionarios_de_respostas:
#       4       arquivo.write(f"{pergunta_dict['pergunta']},{pergunta_dict['resposta']}\n")
#
# NameError: name 'lista_de_dicionarios_de_respostas' is not defined

# %%
df_perguntas_e_respostas = pd.DataFrame(lista_de_dicionarios_de_respostas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1229031430.py in <cell line: 0>()
# ----> 1 df_perguntas_e_respostas = pd.DataFrame(lista_de_dicionarios_de_respostas)
#
# NameError: name 'pd' is not defined

# %%
df_perguntas_e_respostas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2444681095.py in <cell line: 0>()
# ----> 1 df_perguntas_e_respostas
#
# NameError: name 'df_perguntas_e_respostas' is not defined

# %%
df_perguntas_e_respostas.to_csv("respostas2.csv", index=False, encoding="utf-8")

# %%
novo_df = pd.read_csv("respostas2.csv")

# %%
novo_df
# Out:
#                                             pergunta  \
# 0            como vou fazer para arrumar um emprego?
# 1                             por que e tao dificil?
# 2                                   a culpa e minha?
# 3                     quando o  brasil vai melhorar?
# 4                                como estudar certo?
# 5  sera que esse curso da escola da nuvem vai rea...
# 6               o que sera de mim se eu n conseguir?
#
#                                             resposta
# 0  Defina seu objetivo, prepare seu currículo, pe...
# 1                           Complexidade e desafios.
# 2                                 Provavelmente não.
# 3                           A cada dia, com esforço.
# 4                            Compreender e praticar.
# 5  Sim, pode, e muito, mas depende do seu esforço...
# 6                                  Você se adaptará.

# %%
import pandas as pd
import numpy as np
import random

# Gerar 50 linhas de dados
num_rows = 50

# Nomes de produtos (exemplo)
product_names = [f'Produto {i+1}' for i in range(num_rows)]

# Categorias de produtos (exemplo)
categories = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros', 'Casa e Decoração']
product_categories = random.choices(categories, k=num_rows)

# Preço do produto (entre 10.00 e 500.00)
product_prices = np.round(np.random.uniform(10.00, 500.00, num_rows), 2)

# Quantidade de itens vendidos (entre 1 e 100)
items_sold = np.random.randint(1, 101, num_rows)

# Avaliação do produto (entre 1.0 e 5.0)
product_ratings = np.round(np.random.uniform(1.0, 5.0, num_rows), 1)

# Criar o DataFrame
df_produtos = pd.DataFrame({
    'nome do produto': product_names,
    'categoria do produto': product_categories,
    'preco do produto': product_prices,
    'quantos itens foram vendidos': items_sold,
    'avaliacão do produto': product_ratings
})

# Exibir as primeiras 5 linhas do DataFrame
display(df_produtos.head())
# Out:
#   nome do produto categoria do produto  preco do produto  \
# 0       Produto 1               Livros            369.71
# 1       Produto 2            Alimentos            438.46
# 2       Produto 3          Eletrônicos             29.52
# 3       Produto 4     Casa e Decoração            478.97
# 4       Produto 5               Livros            284.73
#
#    quantos itens foram vendidos  avaliacão do produto
# 0                            67                   4.5
# 1                            33                   4.9
# 2                            73                   1.1
# 3                            45                   2.6
# 4                            28                   3.3

# %%
df_produtos
# Out:
#    nome do produto categoria do produto  preco do produto  \
# 0        Produto 1               Livros            110.45
# 1        Produto 2     Casa e Decoração            187.34
# 2        Produto 3     Casa e Decoração            153.43
# 3        Produto 4          Eletrônicos            353.14
# 4        Produto 5          Eletrônicos            439.97
# 5        Produto 6     Casa e Decoração            214.87
# 6        Produto 7               Livros            158.16
# 7        Produto 8               Roupas            236.12
# 8        Produto 9          Eletrônicos            178.69
# 9       Produto 10               Livros            378.04
# 10      Produto 11     Casa e Decoração            195.75
# 11      Produto 12            Alimentos            370.35
# 12      Produto 13            Alimentos            167.75
# 13      Produto 14               Livros             35.82
# 14      Produto 15     Casa e Decoração            367.49
# ...

# %%
df_produtos["categoria do produto"].unique()
# Out:
# array(['Livros', 'Alimentos', 'Eletrônicos', 'Casa e Decoração', 'Roupas'],
#       dtype=object)

# %%
set(df_produtos["categoria do produto"])
# Out:
# {'Alimentos', 'Casa e Decoração', 'Eletrônicos', 'Livros', 'Roupas'}

# %%
df_produtos [df_produtos["categoria do produto"] == "Eletrônicos"]
# Out:
#    nome do produto categoria do produto  preco do produto  \
# 2        Produto 3          Eletrônicos             29.52
# 6        Produto 7          Eletrônicos            487.68
# 10      Produto 11          Eletrônicos            487.14
# 16      Produto 17          Eletrônicos            122.60
# 21      Produto 22          Eletrônicos            397.07
# 27      Produto 28          Eletrônicos            485.03
# 32      Produto 33          Eletrônicos             35.84
# 44      Produto 45          Eletrônicos            464.79
# 47      Produto 48          Eletrônicos            398.26
# 48      Produto 49          Eletrônicos            136.85
#
#     quantos itens foram vendidos  avaliacão do produto
# 2                             73                   1.1
# 6                             20                   2.4
# 10                            38                   1.4
# 16                            76                   1.9
# ...

# %%
df_produtos.iloc[0:15]
# Out:
#    nome do produto categoria do produto  preco do produto  \
# 0        Produto 1               Livros            369.71
# 1        Produto 2            Alimentos            438.46
# 2        Produto 3          Eletrônicos             29.52
# 3        Produto 4     Casa e Decoração            478.97
# 4        Produto 5               Livros            284.73
# 5        Produto 6            Alimentos            370.06
# 6        Produto 7          Eletrônicos            487.68
# 7        Produto 8               Roupas            309.72
# 8        Produto 9               Livros             71.35
# 9       Produto 10               Livros            367.52
# 10      Produto 11          Eletrônicos            487.14
# 11      Produto 12     Casa e Decoração            177.98
# 12      Produto 13               Roupas            248.81
# 13      Produto 14               Roupas            429.09
# 14      Produto 15               Roupas            295.81
#
# ...

# %%
df_produtos_indexado = df_produtos.set_index('nome do produto')
display(df_produtos_indexado.head())
# Out:
#                 categoria do produto  preco do produto  \
# nome do produto
# Produto 1                     Livros            369.71
# Produto 2                  Alimentos            438.46
# Produto 3                Eletrônicos             29.52
# Produto 4           Casa e Decoração            478.97
# Produto 5                     Livros            284.73
#
#                  quantos itens foram vendidos  avaliacão do produto
# nome do produto
# Produto 1                                  67                   4.5
# Produto 2                                  33                   4.9
# Produto 3                                  73                   1.1
# Produto 4                                  45                   2.6
# Produto 5                                  28                   3.3

# %%
df_produtos_indexado.loc["Produto 15": "Produto 30"]
# Out:
#                 categoria do produto  preco do produto  \
# nome do produto
# Produto 15                    Roupas            295.81
# Produto 16                 Alimentos            230.84
# Produto 17               Eletrônicos            122.60
# Produto 18          Casa e Decoração             23.79
# Produto 19          Casa e Decoração            362.72
# Produto 20                    Livros            180.94
# Produto 21                    Livros            348.32
# Produto 22               Eletrônicos            397.07
# Produto 23                    Roupas            386.85
# Produto 24                    Roupas            336.89
# Produto 25                    Livros            164.64
# Produto 26                 Alimentos            256.74
# Produto 27                    Roupas             46.53
# Produto 28               Eletrônicos            485.03
# Produto 29                 Alimentos             55.68
# Produto 30                    Roupas             71.95
#
# ...

# %%
df_produtos_indexado.loc["Produto 45", "preco do produto"]
# Out:
# np.float64(464.79)

# %%
eletronicos= df_produtos_indexado[df_produtos_indexado["categoria do produto"] == "Eletrônicos"]
df_produtos_indexado.loc[eletronicos.index,["preco do produto", "quantos itens foram vendidos"]]
# Out:
#                  preco do produto  quantos itens foram vendidos
# nome do produto
# Produto 3                   29.52                            73
# Produto 7                  487.68                            20
# Produto 11                 487.14                            38
# Produto 17                 122.60                            76
# Produto 22                 397.07                            49
# Produto 28                 485.03                             1
# Produto 33                  35.84                             4
# Produto 45                 464.79                            45
# Produto 48                 398.26                            10
# Produto 49                 136.85                            97

# %%
roupas = df_produtos_indexado[df_produtos_indexado["categoria do produto"]== "Roupas"]
df_produtos_indexado.loc[roupas.index, "categoria do produto"] = "Moda"

# %%
df_produtos_indexado
# Out:
#                 categoria do produto  preco do produto  \
# nome do produto
# Produto 1                     Livros            369.71
# Produto 2                  Alimentos            438.46
# Produto 3                Eletrônicos             29.52
# Produto 4           Casa e Decoração            478.97
# Produto 5                     Livros            284.73
# Produto 6                  Alimentos            370.06
# Produto 7                Eletrônicos            487.68
# Produto 8                       Moda            309.72
# Produto 9                     Livros             71.35
# Produto 10                    Livros            367.52
# Produto 11               Eletrônicos            487.14
# Produto 12          Casa e Decoração            177.98
# Produto 13                      Moda            248.81
# Produto 14                      Moda            429.09
# Produto 15                      Moda            295.81
# Produto 16                 Alimentos            230.84
# ...

# %%
df_produtos_indexado["categoria do produto"].unique()
# Out:
# array(['Livros', 'Alimentos', 'Eletrônicos', 'Casa e Decoração', 'Moda'],
#       dtype=object)

# %%
df_reviews = pd.read_csv("/content/reviews.csv")

# %%
df_reviews.head()
# Out:
#        reviewerID        asin  reviewerName  \
# 0  A2FII3I2MBMUIA  B007WTAJTO           1K3
# 1   A3H99DFEG68SR  B007WTAJTO           1m2
# 2  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men
# 3  A2IDCSC6NVONIZ  B007WTAJTO       2Cents!
# 4  A26YHXZD5UFPVQ  B007WTAJTO    2K1Toaster
#
#                                           reviewText  unixReviewTime  \
# 0  it works as expected. I should have sprung for...      1356220800
# 1  This think has worked out great.Had a diff. br...      1384992000
# 2  Bought it with Retail Packaging, arrived legit...      1373673600
# 3  It's mini storage.  It doesn't do anything els...      1367193600
# 4  I have it in my phone and it never skips a bea...      1382140800
#
#    reviewTime  day_diff  helpful_yes  total_vote
# 0  23/12/2012       715            0           0
# 1  21/11/2013       382            0           0
# 2  13/07/2013       513            0           0
# 3  29/04/2013       588            0           0
# ...

# %%
coluna_de_reviews = df_reviews["reviewText"]
coluna_de_reviews
# Out:
# 0     it works as expected. I should have sprung for...
# 1     This think has worked out great.Had a diff. br...
# 2     Bought it with Retail Packaging, arrived legit...
# 3     It's mini storage.  It doesn't do anything els...
# 4     I have it in my phone and it never skips a bea...
# 5     It works, but file writes are a bit slower tha...
# 6     I bought 2 of those SanDisk 32 GB microSD , us...
# 7     The memory card is an excellent condition and ...
# 8     I bougth this micro SD card after some trubles...
# 9     Ordered this for a Galaxy S3.  Lasted a few mo...
# 10    more like 8mb/s in my Note 10.1 and that's usi...
# 11    I used this for a few months in my phone, then...
# 12    everything about it was great, except for the ...
# 13    Used in my phone it's plenty fast and works ju...
# 14    This card advertises itself as UHS1 but it's a...
# 15    I bought this SD card for my android phone thi...
# 16    good card. work as describes. haven't had any ...
# ...

# %%
lista_de_analise_de_sentimentos = []

for review_numero, resenha in enumerate(coluna_de_reviews):
    resposta = client.models.generate_content(
      model="gemini-2.5-flash",
      contents=f"""voce vai analisar a resenha que eu te mandarei abaixo, e retornar com uma analise de sentimento.
                   voce deve responder APENAS com uma das seguintes palavras: 'positiva','negativa'ou 'neutra',
                   indicando o sentimento relativo aquela resenha especifica.

                   Exemplos:
                   'eu adorei esse produto' -> positiva
                   'gostei mas pode melhorar' -> neutra
                   'odiei esse produto'-> negativa
                   segue a resenha a ser analisada: {resenha}
                   """
      )
    lista_de_analise_de_sentimentos.append(resposta.text)
    print(f"Resenha{review_numero}: '{resenha}' -> sentimento: {resposta.text}")
# Out:
# Resenha0: 'it works as expected. I should have sprung for the higher capacity.  I think its made a bit cheesier than the earlier versions; the paint looks not as clean as before' -> sentimento: negativa
# Resenha1: 'This think has worked out great.Had a diff. bran 64gb card and if went south after 3 months.This one has held up pretty well since I had my S3, now on my Note3.*** update 3/21/14I've had this for a few months and have had ZERO issue's since it was transferred from my S3 to my Note3 and into a note2. This card is reliable and solid!Cheers!' -> sentimento: positiva
# Resenha2: 'Bought it with Retail Packaging, arrived legit, in a orange envelope, english version not asian like the picture shows. arrived quickly, bought a 32 and 16 both retail packaging for my htc one sv and Lg Optimus, both cards in working order, probably best price you'll get for a nice sd card' -> sentimento: positiva
# ...

# %%
lista_de_analise_de_sentimentos
# Out:
# ['negativa', 'positiva', 'positiva', 'positiva', 'positiva', 'negativa']

# %%
df_reviews["Analises de Sentimentos"] = lista_de_analise_de_sentimentos
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3890609178.py in <cell line: 0>()
# ----> 1 df_reviews["Analises de Sentimentos"] = lista_de_analise_de_sentimentos
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# ...
